# %% [markdown]
# # suyog khadka

# %% [markdown]
# Hello hello what is up i am suyog khadka

# %%
# Initialize your variables here (e.g., list = [], count = 0, sum = 0)
while True:
    data = input("Enter value: ")
    if data == "":
        break  # STOP the loop
    
    # DO WORK HERE:
    # 1. Convert to int? (num = int(data))
    # 2. Add to list? (my_list.append(data))
    # 3. Add to sum? (total += num)
